# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import sklearn as skl
import tensorflow as tf

# %%
df = pd.read_csv("Data/carsAvgPrice.csv")
df.head()
# Out:
#    Unnamed: 0  Brand Model  Year Status   Mileage  Age  AveragePrice
# 0           0  Acura   ILX  2013   Used   86557.0   11       13900.0
# 1           1  Acura   ILX  2014   Used  148266.0   10       10996.0
# 2           2  Acura   ILX  2015   Used   77223.0    9       13650.0
# 3           3  Acura   ILX  2016   Used   56546.0    8       16900.0
# 4           4  Acura   ILX  2016   Used   72301.0    8       16999.0

# %%
df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    Brand Model  Year Status   Mileage  Age  AveragePrice
# 0  Acura   ILX  2013   Used   86557.0   11       13900.0
# 1  Acura   ILX  2014   Used  148266.0   10       10996.0
# 2  Acura   ILX  2015   Used   77223.0    9       13650.0
# 3  Acura   ILX  2016   Used   56546.0    8       16900.0
# 4  Acura   ILX  2016   Used   72301.0    8       16999.0

# %%
brandCount = df["Brand"].value_counts()
brandCount[brandCount<1000]
# Out:
# Brand
# Subaru                 982
# Volvo                  916
# Tesla                  881
# Lincoln                867
# Infiniti               817
# RAM                    775
# Genesis                516
# Jaguar                 331
# Buick                  324
# Chrysler               307
# Mitsubishi             279
# Maserati               191
# MINI                   181
# Alfa Romeo             149
# Bentley                119
# Pontiac                105
# Ferrari                 93
# Lamborghini             85
# FIAT                    77
# Rolls-Royce             64
# Aston Martin            61
# Scion                   52
# Hummer                  47
# Polestar                45
# McLaren                 40
# Rivian                  32
# Saturn                  30
# Mercury                 18
# Lucid                   13
# Saab                    13
# Lotus                   11
# Smart                    8
# Suzuki                   6
# Karma                    6
# Plymouth                 4
# Oldsmobile               3
# International Scout      1
# Bugatti                  1
# Eagle                    1
# Geo                      1
# Isuzu                    1
# Maybach                  1
# Name: count, dtype: int64

# %%
brands_to_replace = list(brandCount[brandCount<1000].index)

for brand in brands_to_replace:
    df['Brand'] = df['Brand'].replace(brand,"Other")

df.drop(df.loc[df['Brand']=='Other'].index,inplace=True)
df["Brand"].value_counts()
# Out:
# Brand
# Toyota        6461
# Ford          6124
# Chevrolet     4546
# BMW           3506
# Lexus         3061
# Honda         2665
# Mercedes      2606
# Audi          2385
# Jeep          2054
# GMC           1949
# Porsche       1691
# Nissan        1578
# Cadillac      1342
# Kia           1273
# Volkswagen    1212
# Mazda         1208
# Acura         1187
# Dodge         1091
# Hyundai       1077
# Land Rover    1057
# Name: count, dtype: int64

# %%
modelCount = df["Model"].value_counts()
modelCount[modelCount<500]
# Out:
# Model
# Camaro          485
# MDX             469
# ES              436
# Bronco          434
# CR-V            432
#                ...
# Pickup Truck      1
# Uplander          1
# Spectra5          1
# Venture           1
# 560 SL            1
# Name: count, Length: 413, dtype: int64

# %%
models_to_replace = list(modelCount[modelCount<500].index)

for model in models_to_replace:
    df['Model'] = df['Model'].replace(model,"Other")

df.drop(df.loc[df['Model']=='Other'].index,inplace=True)
df["Model"].value_counts()
# Out:
# Model
# F-150             1796
# Corvette           954
# 4Runner            940
# Tundra             932
# Mustang            871
# Wrangler           807
# Yukon              801
# Silverado          798
# RX                 774
# Tacoma             773
# Sierra             760
# Grand Cherokee     744
# Tahoe              720
# Range Rover        714
# Highlander         694
# F-250              653
# RAV4               650
# Expedition         582
# Camry              557
# X5                 555
# 911                555
# Accord             554
# Escalade           533
# Civic              512
# GX                 500
# Name: count, dtype: int64

# %%
""" print(f"Min: {df["AveragePrice"].min()}")
print(f"Max: {df["AveragePrice"].max()}")
priceRangeDict = {
    'GreaterThan1M' : 1,
    'GreaterThan500k': 2,
    'GreaterThan100k' : 3,
    'GreaterThan50k' : 4,
    'GreaterThan20k' : 5,
    'LessThan10k' : 6,
    'LessThan5k' : 7
}

df.loc[df['AveragePrice']>1000000,'AveragePrice'] = priceRangeDict['GreaterThan1M']
df.loc[(df['AveragePrice']<1000000) & (df['AveragePrice']>500000),'AveragePrice'] = priceRangeDict['GreaterThan500k']
df.loc[(df['AveragePrice']<100000) & (df['AveragePrice']>50000),'AveragePrice'] = priceRangeDict['GreaterThan100k']
df.loc[(df['AveragePrice']<50000) & (df['AveragePrice']>20000),'AveragePrice'] = priceRangeDict['GreaterThan50k']
df.loc[(df['AveragePrice']<20000) & (df['AveragePrice']>10000),'AveragePrice'] = priceRangeDict['GreaterThan20k']
df.loc[(df['AveragePrice']<10000) & (df['AveragePrice']>5000),'AveragePrice'] = priceRangeDict['LessThan10k']
df.loc[(df['AveragePrice']<5000),'AveragePrice'] = priceRangeDict['LessThan5k'] """
# Out:
# ' print(f"Min: {df["AveragePrice"].min()}")\nprint(f"Max: {df["AveragePrice"].max()}")\npriceRangeDict = {\n    \'GreaterThan1M\' : 1,\n    \'GreaterThan500k\': 2,\n    \'GreaterThan100k\' : 3,\n    \'GreaterThan50k\' : 4,\n    \'GreaterThan20k\' : 5,\n    \'LessThan10k\' : 6,\n    \'LessThan5k\' : 7\n}\n\ndf.loc[df[\'AveragePrice\']>1000000,\'AveragePrice\'] = priceRangeDict[\'GreaterThan1M\']\ndf.loc[(df[\'AveragePrice\']<1000000) & (df[\'AveragePrice\']>500000),\'AveragePrice\'] = priceRangeDict[\'GreaterThan500k\']\ndf.loc[(df[\'AveragePrice\']<100000) & (df[\'AveragePrice\']>50000),\'AveragePrice\'] = priceRangeDict[\'GreaterThan100k\']\ndf.loc[(df[\'AveragePrice\']<50000) & (df[\'AveragePrice\']>20000),\'AveragePrice\'] = priceRangeDict[\'GreaterThan50k\']\ndf.loc[(df[\'AveragePrice\']<20000) & (df[\'AveragePrice\']>10000),\'AveragePrice\'] = priceRangeDict[\'GreaterThan20k\']\ndf.loc[(df[\'AveragePrice\']<10000) & (df[\'AveragePrice\']>5000),\'AveragePrice\'] = priceRangeDict[\'LessThan10k\']\ndf.loc[(df[\'AveragePrice\']<5000),\'AveragePrice\'] = priceRangeDict[\'LessThan5k\'] '

# %%
df_dummy = pd.get_dummies(df,dtype=int)
df_dummy.head()
# Out:
#       Year   Mileage  Age  AveragePrice  Brand_BMW  Brand_Cadillac  \
# 6062  2004   44671.0   20       12500.0          1               0
# 6063  2009  108871.0   15        9495.0          1               0
# 6064  2010   63146.0   14        8900.0          1               0
# 6065  2011   39873.0   13       16850.0          1               0
# 6066  2011   46114.0   13       27588.0          1               0
#
#       Brand_Chevrolet  Brand_Ford  Brand_GMC  Brand_Honda  ...  \
# 6062                0           0          0            0  ...
# 6063                0           0          0            0  ...
# 6064                0           0          0            0  ...
# 6065                0           0          0            0  ...
# 6066                0           0          0            0  ...
#
#       Model_Silverado  Model_Tacoma  Model_Tahoe  Model_Tundra  \
# 6062                0             0            0             0
# 6063                0             0            0             0
# 6064                0             0            0             0
# 6065                0             0            0             0
# 6066                0             0            0             0
#
#       Model_Wrangler  Model_X5  Model_Yukon  Status_Certified  Status_New  \
# 6062               0         1            0                 0           0
# 6063               0         1            0                 0           0
# 6064               0         1            0                 0           0
# 6065               0         1            0                 0           0
# 6066               0         1            0                 0           0
#
#       Status_Used
# 6062            1
# 6063            1
# 6064            1
# 6065            1
# 6066            1
#
# [5 rows x 44 columns]

# %%
y = df_dummy['AveragePrice']
X = df_dummy.drop(columns=['AveragePrice','Year'])

# %%
y
# Out:
# 6062     12500.000000
# 6063      9495.000000
# 6064      8900.000000
# 6065     16850.000000
# 6066     27588.000000
#              ...
# 54248    48490.000000
# 54249    50849.000000
# 54250    58492.000000
# 54251    64771.000000
# 54252    64178.888889
# Name: AveragePrice, Length: 18729, dtype: float64

# %%
X
# Out:
#         Mileage  Age  Brand_BMW  Brand_Cadillac  Brand_Chevrolet  Brand_Ford  \
# 6062    44671.0   20          1               0                0           0
# 6063   108871.0   15          1               0                0           0
# 6064    63146.0   14          1               0                0           0
# 6065    39873.0   13          1               0                0           0
# 6066    46114.0   13          1               0                0           0
# ...         ...  ...        ...             ...              ...         ...
# 54248   33696.0    1          0               0                0           0
# 54249     105.0    0          0               0                0           0
# 54250     186.0    0          0               0                0           0
# 54251    1455.0    0          0               0                0           0
# 54252       0.0    0          0               0                0           0
#
#        Brand_GMC  Brand_Honda  Brand_Jeep  Brand_Land Rover  ...  \
# 6062           0            0           0                 0  ...
# 6063           0            0           0                 0  ...
# 6064           0            0           0                 0  ...
# 6065           0            0           0                 0  ...
# 6066           0            0           0                 0  ...
# ...          ...          ...         ...               ...  ...
# 54248          0            0           0                 0  ...
# 54249          0            0           0                 0  ...
# 54250          0            0           0                 0  ...
# 54251          0            0           0                 0  ...
# 54252          0            0           0                 0  ...
#
#        Model_Silverado  Model_Tacoma  Model_Tahoe  Model_Tundra  \
# 6062                 0             0            0             0
# 6063                 0             0            0             0
# 6064                 0             0            0             0
# 6065                 0             0            0             0
# 6066                 0             0            0             0
# ...                ...           ...          ...           ...
# 54248                0             0            0             1
# 54249                0             0            0             1
# 54250                0             0            0             1
# 54251                0             0            0             1
# 54252                0             0            0             1
#
#        Model_Wrangler  Model_X5  Model_Yukon  Status_Certified  Status_New  \
# 6062                0         1            0                 0           0
# 6063                0         1            0                 0           0
# 6064                0         1            0                 0           0
# 6065                0         1            0                 0           0
# 6066                0         1            0                 0           0
# ...               ...       ...          ...               ...         ...
# 54248               0         0            0                 0           0
# 54249               0         0            0                 1           0
# 54250               0         0            0                 1           0
# 54251               0         0            0                 1           0
# 54252               0         0            0                 0           1
#
#        Status_Used
# 6062             1
# 6063             1
# 6064             1
# 6065             1
# 6066             1
# ...            ...
# 54248            1
# 54249            0
# 54250            0
# 54251            0
# 54252            0
#
# [18729 rows x 42 columns]

# %%
#Train Test split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
scaler = StandardScaler()

# %%
#scale data
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#model Random Forest  
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=50, random_state=13)
rf_model = rf_model.fit(X_train_scaled,y_train)
predictions = rf_model.predict(X_test_scaled)

# %%
predictions_df = X_test.copy()
predictions_df["Actual_price"] = y_test
predictions_df["Predict_price"] = predictions
predictions_df["Error %"] = (abs(predictions_df["Predict_price"]-predictions_df["Actual_price"])/predictions_df["Actual_price"])*100
predictions_df.head()
# Out:
#        Mileage  Age  Brand_BMW  Brand_Cadillac  Brand_Chevrolet  Brand_Ford  \
# 35456  38931.0    9          0               0                0           0
# 48281  24569.0    4          0               0                0           0
# 16234  28365.0    3          0               0                0           1
# 50655  64819.0    3          0               0                0           0
# 6313   44030.0    4          1               0                0           0
#
#        Brand_GMC  Brand_Honda  Brand_Jeep  Brand_Land Rover  ...  \
# 35456          0            0           0                 0  ...
# 48281          0            0           0                 0  ...
# 16234          0            0           0                 0  ...
# 50655          0            0           0                 0  ...
# 6313           0            0           0                 0  ...
#
#        Model_Tundra  Model_Wrangler  Model_X5  Model_Yukon  Status_Certified  \
# 35456             0               0         0            0                 0
# 48281             0               0         0            0                 0
# 16234             0               0         0            0                 0
# 50655             0               0         0            0                 0
# 6313              0               0         1            0                 0
#
#        Status_New  Status_Used  Actual_price  Predict_price    Error %
# 35456           0            1       24394.0       28370.38  16.300648
# 48281           0            1       37450.0       43347.40  15.747397
# 16234           0            1       38491.0       59511.66  54.611883
# 50655           0            1       42500.0       31863.64  25.026729
# 6313            0            1       52199.0       39506.74  24.315140
#
# [5 rows x 45 columns]

# %%
predictions_df.loc[:,'Error %'].mean()
# Out:
# 15.759791853597088

# %%
result_df = pd.merge(predictions_df,df,how='left',left_index=True,right_index=True)
result_df = result_df[["Brand","Model","Year","Status","Mileage_y","AveragePrice","Actual_price","Predict_price","Error %"]]
result_df
# Out:
#            Brand       Model  Year     Status  Mileage_y  AveragePrice  \
# 35456      Lexus          RX  2015       Used    38931.0       24394.0
# 48281     Toyota     4Runner  2020       Used    24569.0       37450.0
# 16234       Ford  Expedition  2021       Used    28365.0       38491.0
# 50655     Toyota  Highlander  2021       Used    64819.0       42500.0
# 6313         BMW          X5  2020       Used    44030.0       52199.0
# ...          ...         ...   ...        ...        ...           ...
# 43787    Porsche         911  2020  Certified    17678.0      133293.0
# 53723     Toyota      Tundra  2020  Certified    21548.0       39296.0
# 35966      Lexus          RX  2021       Used    45131.0       44394.0
# 20888       Ford     Mustang  2022       Used     5697.0       38499.0
# 10129  Chevrolet    Corvette  1998       Used    52570.0       17772.0
#
#        Actual_price  Predict_price    Error %
# 35456       24394.0       28370.38  16.300648
# 48281       37450.0       43347.40  15.747397
# 16234       38491.0       59511.66  54.611883
# 50655       42500.0       31863.64  25.026729
# 6313        52199.0       39506.74  24.315140
# ...             ...            ...        ...
# 43787      133293.0      138654.02   4.021982
# 53723       39296.0       43099.98   9.680324
# 35966       44394.0       42916.30   3.328603
# 20888       38499.0       40627.02   5.527468
# 10129       17772.0       17223.38   3.086991
#
# [4683 rows x 9 columns]

# %%
import hvplot.pandas
result_df.hvplot.scatter(
    x='Actual_price',
    y='Predict_price',
    color='Brand'
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e3a59ea8-39a2-4fe4-8186-3fb680541220" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"43d968e6-96e2-4381-ab02-e0e32d24ec28":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"f1807f17f21f41a184a15b7895a52711","client_comm_id":"1b3f70b2bb774aac9ae0e765bb7556e6"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"43d968e6-96e2-4381-ab02-e0e32d24ec28","roots":{"p1002":"e3a59ea8-39a2-4fe4-8186-3fb680541220"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# :Scatter   [Actual_price]   (Predict_price,Brand)
